# %% [markdown]
# ## EDA portfolio for MMA Predictor

# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns

# %% [markdown]
# ### Loading in fighter data

# %%
fighter_df = pd.read_csv('archive/preprocessed_data.csv')

# %% [markdown]
# ## Lets understand which features make the most sense

# %%
fighter_df.head()
# Out:
#   Winner  title_bout  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0    Red       False  0.000000           0.0           0.420000
# 1    Red       False  0.500000           0.0           0.660000
# 2    Red       False  0.015625           0.0           0.450000
# 3   Blue       False  0.015625           0.0           0.450000
# 4   Blue       False  0.125000           0.0           0.535625
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0                0.49500         0.330           0.36000       0.500000
# 1                0.30500         0.300           0.50000       1.500000
# 2                0.42750         0.250           0.20000       0.148468
# 3                0.42750         0.250           0.20000       0.148468
# 4                0.57875         0.185           0.16625       0.125000
#
#    B_avg_opp_SUB_ATT  ...  B_Stance_Open Stance  B_Stance_Orthodox  \
# 0           1.000000  ...                     0                  1
# ...

# %%
#fighter_df["Winner_Red"] = fighter_df["Winner"].apply(lambda x: 1 if x == "Red" else 0)
#fighter_df.drop(columns = ['Winner'], inplace = True)

# %%
fighter_df.head()
# Out:
#    title_bout  B_avg_KD  B_avg_opp_KD  B_avg_SIG_STR_pct  \
# 0       False  0.000000           0.0           0.420000
# 1       False  0.500000           0.0           0.660000
# 2       False  0.015625           0.0           0.450000
# 3       False  0.015625           0.0           0.450000
# 4       False  0.125000           0.0           0.535625
#
#    B_avg_opp_SIG_STR_pct  B_avg_TD_pct  B_avg_opp_TD_pct  B_avg_SUB_ATT  \
# 0                0.49500         0.330           0.36000       0.500000
# 1                0.30500         0.300           0.50000       1.500000
# 2                0.42750         0.250           0.20000       0.148468
# 3                0.42750         0.250           0.20000       0.148468
# 4                0.57875         0.185           0.16625       0.125000
#
#    B_avg_opp_SUB_ATT  B_avg_REV  ...  B_Stance_Orthodox  B_Stance_Sideways  \
# 0           1.000000       0.00  ...                  1                  0
# ...

# %%
fighter_df.groupby("Winner_Red").mean()
fighter_df.corr()['Winner_Red'].sort_values(ascending = False)
# Out:
# Winner_Red                  1.000000
# R_Weight_lbs                0.094686
# B_Weight_lbs                0.087404
# R_avg_TD_pct                0.085872
# weight_class_OpenWeight     0.084536
#                               ...
# R_avg_opp_SIG_STR_landed   -0.144787
# R_age                      -0.156431
# R_losses                   -0.159319
# B_draw                           NaN
# R_draw                           NaN
# Name: Winner_Red, Length: 160, dtype: float64
